# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# from sklearn.linear_model import LinearRegression

# %matplotlib inline

sns.set()

one_piece = pd.read_csv("one_piece.csv")
big_three = pd.read_csv("big_three.csv")
naruto = pd.read_csv('naruto.csv', encoding_errors='ignore')

# %%
one_piece.head()
# Out:
#    Unnamed: 0    rank trend  season  episode  \
# 0           0  24,129    18       1        1
# 1           1  29,290    11       1        2
# 2           2  32,043     7       1        3
# 3           3  28,818     8       1        4
# 4           4  37,113     4       1        5
#
#                                                 name  start total_votes  \
# 0  I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1  The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2  Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
#
#    average_rating
# 0             7.6
# 1             7.8
# 2             7.7
# 3             8.1
# 4             7.5

# %%
big_three.head(60)
# Out:
#                                Arc  Start onChapter  TotalChapters  \
# 0                 Romance Dawn Arc              1.0              7
# 1                  Orange Town Arc              8.0             14
# 2                Syrup Village Arc             22.0             20
# 3                      Baratie Arc             42.0             27
# 4                  Arlong Park Arc             69.0             27
# 5             Buggy Side Story Arc              0.0              0
# 6                    Loguetown Arc             96.0              5
# 7               Warship Island Arc              0.0              0
# 8             Reverse Mountain Arc            101.0              5
# 9                 Whiskey Peak Arc            106.0              9
# 10           Koby and Helmeppo Arc              0.0              0
# 11               Little Garden Arc            115.0             15
# 12                 Drum Island Arc            130.0             25
# ...

# %%
one_piece.describe()
# Out:
#        Unnamed: 0  season     episode        start  average_rating
# count  958.000000   958.0  958.000000   958.000000      958.000000
# mean   478.500000     1.0  479.500000  2010.231733        7.796555
# std    276.695079     0.0  276.695079     6.049997        0.589670
# min      0.000000     1.0    1.000000  1999.000000        5.600000
# 25%    239.250000     1.0  240.250000  2005.000000        7.500000
# 50%    478.500000     1.0  479.500000  2010.000000        7.800000
# 75%    717.750000     1.0  718.750000  2015.000000        8.200000
# max    957.000000     1.0  958.000000  2021.000000        9.600000

# %%
big_three.describe()
# Out:
#        Start onChapter  TotalChapters   TotalPages  Start onEpisode  \
# count       105.000000     105.000000   105.000000       105.000000
# mean        230.410476      23.561905   441.885714       269.314286
# std         274.069322      31.266203   584.649473       243.398546
# min           0.000000       0.000000     0.000000         0.000000
# 25%           0.000000       0.000000     0.000000        78.000000
# 50%         115.000000      15.000000   278.000000       197.000000
# 75%         424.000000      33.000000   627.000000       408.000000
# max         958.000000     208.000000  3952.000000       959.000000
#
#        TotalEpisodes  TotalMinutes(avg 24)
# count     105.000000            105.000000
# mean       20.133333            483.200000
# std        19.949006            478.776132
# min         0.000000              0.000000
# 25%         6.000000            144.000000
# 50%        16.000000            384.000000
# 75%        26.000000            624.000000
# ...

# %%
one_piece.head(880)
# Out:
#      Unnamed: 0    rank trend  season  episode  \
# 0             0  24,129    18       1        1
# 1             1  29,290    11       1        2
# 2             2  32,043     7       1        3
# 3             3  28,818     8       1        4
# 4             4  37,113     4       1        5
# ..          ...     ...   ...     ...      ...
# 875         875  84,584     1       1      876
# 876         876  38,952    20       1      877
# 877         877  81,085     1       1      878
# 878         878  99,319     1       1      879
# 879         879  91,492     3       1      880
#
#                                                   name  start total_votes  \
# 0    I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1    The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2    Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3         Luffy's Past! The Red-haired Shanks Appears!   1999         449
# ...

# %%
naruto.head()
# Out:
#    Unnamed: 0  Num_episode                        Title                Type  \
# 0           1            1                   Homecoming  Mixed Canon/Filler
# 1           2            2  The Akatsuki Makes Its Move  Mixed Canon/Filler
# 2           3            3      The Results of Training  Mixed Canon/Filler
# 3           4            4   The Jinchuriki of the Sand  Mixed Canon/Filler
# 4           5            5     The Kazekage Stands Tall  Mixed Canon/Filler
#
#    Year_launch  Rate  Votes                Saga     Airdate
# 0         2007   8.2    728  s1 Kazekage Rescue  2007-02-15
# 1         2007   8.0    575  s1 Kazekage Rescue  2007-02-15
# 2         2007   8.0    508  s1 Kazekage Rescue  2007-02-22
# 3         2007   8.2    517  s1 Kazekage Rescue  2007-03-01
# 4         2007   8.2    486  s1 Kazekage Rescue  2007-03-15

# %%
naruto.shape
# Out:
# (500, 9)

# %%
one_piece.shape
# Out:
# (958, 9)

# %%
big_three.shape
# Out:
# (105, 10)

# %%
naruto.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Num_episode',
#  'Title',
#  'Type',
#  'Year_launch',
#  'Rate',
#  'Votes',
#  'Saga',
#  'Airdate']

# %%
big_three.columns.to_list()
# Out:
# ['Arc',
#  'Start onChapter',
#  'TotalChapters',
#  'TotalPages',
#  'Manga%',
#  'Start onEpisode',
#  'TotalEpisodes',
#  'TotalMinutes(avg 24)',
#  'Anime%',
#  'BigThree']

# %%
one_piece.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'rank',
#  'trend',
#  'season',
#  'episode',
#  'name',
#  'start',
#  'total_votes',
#  'average_rating']

# %%
one_piece = one_piece.copy()
big_three = big_three.copy()
naruto = naruto.copy()

# %%
one_piece.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      958 non-null    int64
#  1   rank            958 non-null    object
#  2   trend           958 non-null    object
#  3   season          958 non-null    int64
#  4   episode         958 non-null    int64
#  5   name            958 non-null    object
#  6   start           958 non-null    int64
#  7   total_votes     958 non-null    object
#  8   average_rating  958 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 67.5+ KB

# %%
naruto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   500 non-null    int64
#  1   Num_episode  500 non-null    int64
#  2   Title        500 non-null    object
#  3   Type         500 non-null    object
#  4   Year_launch  500 non-null    int64
#  5   Rate         500 non-null    float64
#  6   Votes        500 non-null    int64
#  7   Saga         500 non-null    object
#  8   Airdate      500 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 35.3+ KB

# %%
big_three.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Arc                   105 non-null    object
#  1   Start onChapter       105 non-null    float64
#  2   TotalChapters         105 non-null    int64
#  3   TotalPages            105 non-null    int64
#  4   Manga%                105 non-null    object
#  5   Start onEpisode       105 non-null    int64
#  6   TotalEpisodes         105 non-null    int64
#  7   TotalMinutes(avg 24)  105 non-null    int64
#  8   Anime%                105 non-null    object
#  9   BigThree              105 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 8.3+ KB

# %%
naruto.isnull().sum()
# Out:
# Unnamed: 0     0
# Num_episode    0
# Title          0
# Type           0
# Year_launch    0
# Rate           0
# Votes          0
# Saga           0
# Airdate        0
# dtype: int64

# %%
one_piece.isnull().sum()
# Out:
# Unnamed: 0        0
# rank              0
# trend             0
# season            0
# episode           0
# name              0
# start             0
# total_votes       0
# average_rating    0
# dtype: int64

# %%
big_three.isnull().sum()
# Out:
# Arc                     0
# Start onChapter         0
# TotalChapters           0
# TotalPages              0
# Manga%                  0
# Start onEpisode         0
# TotalEpisodes           0
# TotalMinutes(avg 24)    0
# Anime%                  0
# BigThree                0
# dtype: int64

# %%
one_piece.drop(columns=['Unnamed: 0'], inplace=True)
one_piece
# Out:
#        rank trend  season  episode  \
# 0    24,129    18       1        1
# 1    29,290    11       1        2
# 2    32,043     7       1        3
# 3    28,818     8       1        4
# 4    37,113     4       1        5
# ..      ...   ...     ...      ...
# 953  41,448    26       1      954
# 954  35,342    44       1      955
# 955  33,715    75       1      956
# 956   2,940   964       1      957
# 957  14,751     -       1      958
#
#                                                   name  start total_votes  \
# 0    I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1    The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2    Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3         Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4    Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
# ..                                                 ...    ...         ...
# ...

# %%
naruto
# Out:
#      Num_episode                                              Title  \
# 0              1                                         Homecoming
# 1              2                        The Akatsuki Makes Its Move
# 2              3                            The Results of Training
# 3              4                         The Jinchuriki of the Sand
# 4              5                           The Kazekage Stands Tall
# ..           ...                                                ...
# 495          496  Hidden Leaf Story, the Perfect Day for a Weddi...
# 496          497  Hidden Leaf Story, the Perfect Day for a Weddi...
# 497          498  Hidden Leaf Story, the Perfect Day for a Weddi...
# 498          499  Hidden Leaf Story, the Perfect Day for a Weddi...
# 499          500  Hidden Leaf Story, the Perfect Day for a Weddi...
#
#                    Type  Year_launch  Rate  Votes                Saga  \
# 0    Mixed Canon/Filler         2007   8.2    728  s1 Kazekage Rescue
# ...

# %%
naruto.columns = naruto.columns.str.lower()
naruto
# Out:
#      num_episode                                              title  \
# 0              1                                         Homecoming
# 1              2                        The Akatsuki Makes Its Move
# 2              3                            The Results of Training
# 3              4                         The Jinchuriki of the Sand
# 4              5                           The Kazekage Stands Tall
# ..           ...                                                ...
# 495          496  Hidden Leaf Story, the Perfect Day for a Weddi...
# 496          497  Hidden Leaf Story, the Perfect Day for a Weddi...
# 497          498  Hidden Leaf Story, the Perfect Day for a Weddi...
# 498          499  Hidden Leaf Story, the Perfect Day for a Weddi...
# 499          500  Hidden Leaf Story, the Perfect Day for a Weddi...
#
#                    type  year_launch  rate  votes                saga  \
# 0    Mixed Canon/Filler         2007   8.2    728  s1 Kazekage Rescue
# ...

# %%
big_three.columns = big_three.columns.str.lower()
big_three
# Out:
#                                    arc  start onchapter  totalchapters  \
# 0                     Romance Dawn Arc              1.0              7
# 1                      Orange Town Arc              8.0             14
# 2                    Syrup Village Arc             22.0             20
# 3                          Baratie Arc             42.0             27
# 4                      Arlong Park Arc             69.0             27
# ..                                 ...              ...            ...
# 100        Zanpakutō Unknown Tales Arc              0.0              0
# 101             Arrancar: Downfall Arc            341.0             83
# 102         Gotei 13 Invading Army Arc              0.0              0
# 103  The Lost Substitute Shinigami Arc            424.0             56
# 104       The 1,000 Year Blood War Arc            480.0            208
#
#      totalpages manga%  start onepisode  totalepisodes  totalminutes(avg 24)  \
# ...

# %%
naruto.title.unique()
# Out:
# array(['Homecoming', 'The Akatsuki Makes Its Move',
#        'The Results of Training', 'The Jinchuriki of the Sand',
#        'The Kazekage Stands Tall', 'Mission Cleared', 'Run, Kankuro',
#        'Team Kakashi, Deployed', "The Jinchuriki's Tears",
#        'Sealing Jutsu: Nine Phantom Dragons',
#        "The Medical Ninja's Student",
#        "The Retired Granny's Determination", 'A Meeting With Destiny',
#        "Naruto's Growth", 'The Secret Weapon is Called....',
#        'The Secret of Jinchuriki', 'The Death of Gaara!',
#        'Charge Tactic! Button Hook Entry!!',
#        "Traps Activate! Team Guy's Enemies", 'Hiruko vs. Two Kunoichi!',
#        "Sasori's Real Face", "Chiyo's Secret Skills", 'Father and Mother',
#        'The Third Kazekage', 'Three Minutes Between Life and Death',
#        'Puppet Fight: 10 vs. 100!', 'Impossible Dream',
#        'Beasts! Alive Again!', 'Kakashi Enlightened!',
#        'Aesthetics of an Instant', 'The Legacy!',
# ...

# %%
big_three.arc.unique()
# Out:
# array(['Romance Dawn Arc', 'Orange Town Arc', 'Syrup Village Arc',
#        'Baratie Arc', 'Arlong Park Arc', 'Buggy Side Story Arc',
#        'Loguetown Arc', 'Warship Island Arc', 'Reverse Mountain Arc',
#        'Whiskey Peak Arc', 'Koby and Helmeppo Arc', 'Little Garden Arc',
#        'Drum Island Arc', 'Alabasta Arc', 'Post-Alabasta Arc',
#        'Goat Island Arc', 'Ruluka Island Arc', 'Jaya Arc', 'Skypiea Arc',
#        'G-8 Arc', 'Long Ring Long Land Arc', "Ocean's Dream Arc",
#        "Foxy's Return Arc", 'Water 7 Arc', 'Enies Lobby Arc',
#        'Post-Enies Lobby Arc', 'Ice Hunter Arc', 'Thriller Bark Arc',
#        'Spa Island Arc', 'Sabaody Archipelago Arc',
#        'Special Historical Arc', 'Amazon Lily Arc', 'Impel Down Arc',
#        'Little East Blue Arc', 'Marineford Arc', 'Post-War Arc',
#        'Return to Sabaody Arc', 'Fishman Island Arc', "Z's Ambition Arc",
#        'Punk Hazard Arc', 'Caesar Retrieval Arc', 'Dressrosa Arc',
# ...

# %%
one_piece.name.unique()
# Out:
# array(["I'm Luffy! The Man Who Will Become the Pirate King!",
#        'The Great Swordsman Appears! Pirate Hunter, Roronoa Zoro',
#        "Morgan vs. Luffy! Who's This Beautiful Young Girl?",
#        "Luffy's Past! The Red-haired Shanks Appears!",
#        'Fear, Mysterious Power! Pirate Clown Captain Buggy!',
#        'Desperate Situation! Beast Tamer Mohji vs. Luffy!',
#        'Sozetsu Ketto! Kengo Zoro VS Kyokugei no Kabaji!',
#        'Shousha wa docchi? Akuma no mi no nouryoku taiketsu!',
#        'Seigi no usotsuki? Kyaputen Usoppu',
#        'Chijou saikyou no hen na yatsu! Saiminjutsushi Jango',
#        'Inbou o abake! Kaizoku shitsuji Kyaputen Kuro',
#        'Gekitotsu! Kuroneko kaizokudan sakamichi no daikoubou!',
#        'Kyoufu no futarigumi! Nyâban kyoudai vs Zoro',
#        'Rufi fukkatsu! Kaya ojousama no kesshi no taikou',
#        'Kuro o taose! Otoko Usoppu namida no ketsui!',
#        'Kaya o mamore! Usoppu kaizokudan daikatsuyaku!',
# ...

# %%
big_three.head()
# Out:
#                  arc  start onchapter  totalchapters  totalpages manga%  \
# 0   Romance Dawn Arc              1.0              7         178   0.9%
# 1    Orange Town Arc              8.0             14         273   1.4%
# 2  Syrup Village Arc             22.0             20         396   2.0%
# 3        Baratie Arc             42.0             27         514   2.6%
# 4    Arlong Park Arc             69.0             27         514   2.6%
#
#    start onepisode  totalepisodes  totalminutes(avg 24) anime%   bigthree
# 0                1              3                    72   0.3%  One Piece
# 1                4              5                   120   0.5%  One Piece
# 2                9             10                   240   1.0%  One Piece
# 3               19             12                   288   1.2%  One Piece
# 4               31             15                   360   1.5%  One Piece

# %%
big_three.rename(columns={'totalchapters': 'total_chapters'}, inplace=True)

big_three.head()
# Out:
#                  arc  start onchapter  total_chapters  totalpages manga%  \
# 0   Romance Dawn Arc              1.0               7         178   0.9%
# 1    Orange Town Arc              8.0              14         273   1.4%
# 2  Syrup Village Arc             22.0              20         396   2.0%
# 3        Baratie Arc             42.0              27         514   2.6%
# 4    Arlong Park Arc             69.0              27         514   2.6%
#
#    start onepisode  totalepisodes  totalminutes(avg 24) anime%   bigthree
# 0                1              3                    72   0.3%  One Piece
# 1                4              5                   120   0.5%  One Piece
# 2                9             10                   240   1.0%  One Piece
# 3               19             12                   288   1.2%  One Piece
# 4               31             15                   360   1.5%  One Piece

# %%
big_three.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   arc                   105 non-null    object
#  1   start onchapter       105 non-null    float64
#  2   total_chapters        105 non-null    int64
#  3   totalpages            105 non-null    int64
#  4   manga%                105 non-null    object
#  5   start onepisode       105 non-null    int64
#  6   totalepisodes         105 non-null    int64
#  7   totalminutes(avg 24)  105 non-null    int64
#  8   anime%                105 non-null    object
#  9   bigthree              105 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 8.3+ KB

# %%
big_three.rename(columns={'totalpages': 'total_pages'}, inplace=True)
big_three.rename(columns={'manga%': 'manga_percentage'}, inplace=True)
big_three.rename(columns={'start onchapter': 'chapter_start'}, inplace=True)
big_three.rename(columns={'start onepisode': 'episode_start'}, inplace=True)
big_three.rename(columns={'totalepisodes': 'total_episodes'}, inplace=True)
big_three.rename(columns={'anime%': 'anime_percentage'}, inplace=True)
big_three.rename(columns={'anime%': 'anime_percentage'}, inplace=True)
big_three.rename(columns={'bigthree': 'anime_name'}, inplace=True)

big_three
# Out:
#                                    arc  chapter_start  total_chapters  \
# 0                     Romance Dawn Arc            1.0               7
# 1                      Orange Town Arc            8.0              14
# 2                    Syrup Village Arc           22.0              20
# 3                          Baratie Arc           42.0              27
# 4                      Arlong Park Arc           69.0              27
# ..                                 ...            ...             ...
# 100        Zanpakutō Unknown Tales Arc            0.0               0
# 101             Arrancar: Downfall Arc          341.0              83
# 102         Gotei 13 Invading Army Arc            0.0               0
# 103  The Lost Substitute Shinigami Arc          424.0              56
# 104       The 1,000 Year Blood War Arc          480.0             208
#
#      total_pages manga_percentage  episode_start  total_episodes  \
# ...

# %%
big_three.drop(columns=['totalminutes(avg 24)'], inplace=True)
big_three
# Out:
#                                    arc  chapter_start  total_chapters  \
# 0                     Romance Dawn Arc            1.0               7
# 1                      Orange Town Arc            8.0              14
# 2                    Syrup Village Arc           22.0              20
# 3                          Baratie Arc           42.0              27
# 4                      Arlong Park Arc           69.0              27
# ..                                 ...            ...             ...
# 100        Zanpakutō Unknown Tales Arc            0.0               0
# 101             Arrancar: Downfall Arc          341.0              83
# 102         Gotei 13 Invading Army Arc            0.0               0
# 103  The Lost Substitute Shinigami Arc          424.0              56
# 104       The 1,000 Year Blood War Arc          480.0             208
#
#      total_pages manga_percentage  episode_start  total_episodes  \
# ...

# %%
one_piece
# Out:
#        rank trend  season  episode  \
# 0    24,129    18       1        1
# 1    29,290    11       1        2
# 2    32,043     7       1        3
# 3    28,818     8       1        4
# 4    37,113     4       1        5
# ..      ...   ...     ...      ...
# 953  41,448    26       1      954
# 954  35,342    44       1      955
# 955  33,715    75       1      956
# 956   2,940   964       1      957
# 957  14,751     -       1      958
#
#                                                   name  start total_votes  \
# 0    I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1    The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2    Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3         Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4    Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
# ..                                                 ...    ...         ...
# ...

# %%
one_piece.drop(columns=['rank'], inplace=True)

# %%
one_piece.drop(columns=['season', 'trend'], inplace=True)

# %%
one_piece.drop(columns=['name'], inplace=True)

# %%
one_piece
# Out:
#      episode  start total_votes  average_rating
# 0          1   1999         647             7.6
# 1          2   1999         473             7.8
# 2          3   1999         428             7.7
# 3          4   1999         449             8.1
# 4          5   1999         370             7.5
# ..       ...    ...         ...             ...
# 953      954   2020         302             7.7
# 954      955   2020         407             7.4
# 955      956   2020         353             8.2
# 956      957   2021       2,862             9.1
# 957      958   2021         746             9.4
#
# [958 rows x 4 columns]

# %%
naruto
# Out:
#      num_episode                                              title  \
# 0              1                                         Homecoming
# 1              2                        The Akatsuki Makes Its Move
# 2              3                            The Results of Training
# 3              4                         The Jinchuriki of the Sand
# 4              5                           The Kazekage Stands Tall
# ..           ...                                                ...
# 495          496  Hidden Leaf Story, the Perfect Day for a Weddi...
# 496          497  Hidden Leaf Story, the Perfect Day for a Weddi...
# 497          498  Hidden Leaf Story, the Perfect Day for a Weddi...
# 498          499  Hidden Leaf Story, the Perfect Day for a Weddi...
# 499          500  Hidden Leaf Story, the Perfect Day for a Weddi...
#
#                    type  year_launch  rate  votes                saga  \
# 0    Mixed Canon/Filler         2007   8.2    728  s1 Kazekage Rescue
# ...

# %%
naruto.drop(columns=['title', 'type', 'saga'], inplace=True)
naruto
# Out:
#      num_episode  year_launch  rate  votes     airdate
# 0              1         2007   8.2    728  2007-02-15
# 1              2         2007   8.0    575  2007-02-15
# 2              3         2007   8.0    508  2007-02-22
# 3              4         2007   8.2    517  2007-03-01
# 4              5         2007   8.2    486  2007-03-15
# ..           ...          ...   ...    ...         ...
# 495          496         2017   7.5    313  2017-02-23
# 496          497         2017   7.2    301  2017-03-02
# 497          498         2017   6.8    305  2017-03-09
# 498          499         2017   7.6    323  2017-03-16
# 499          500         2017   8.8   1288  2017-03-23
#
# [500 rows x 5 columns]

# %%
big_three
# Out:
#                                    arc  chapter_start  total_chapters  \
# 0                     Romance Dawn Arc            1.0               7
# 1                      Orange Town Arc            8.0              14
# 2                    Syrup Village Arc           22.0              20
# 3                          Baratie Arc           42.0              27
# 4                      Arlong Park Arc           69.0              27
# ..                                 ...            ...             ...
# 100        Zanpakutō Unknown Tales Arc            0.0               0
# 101             Arrancar: Downfall Arc          341.0              83
# 102         Gotei 13 Invading Army Arc            0.0               0
# 103  The Lost Substitute Shinigami Arc          424.0              56
# 104       The 1,000 Year Blood War Arc          480.0             208
#
#      total_pages manga_percentage  episode_start  total_episodes  \
# ...

# %%
big_three.drop(columns=['chapter_start', 'episode_start'], inplace=True)
big_three
# Out:
#                                    arc  total_chapters  total_pages  \
# 0                     Romance Dawn Arc               7          178
# 1                      Orange Town Arc              14          273
# 2                    Syrup Village Arc              20          396
# 3                          Baratie Arc              27          514
# 4                      Arlong Park Arc              27          514
# ..                                 ...             ...          ...
# 100        Zanpakutō Unknown Tales Arc               0            0
# 101             Arrancar: Downfall Arc              83         1577
# 102         Gotei 13 Invading Army Arc               0            0
# 103  The Lost Substitute Shinigami Arc              56         1064
# 104       The 1,000 Year Blood War Arc             208         3952
#
#     manga_percentage  total_episodes anime_percentage anime_name
# 0               0.9%               3             0.3%  One Piece
# ...

# %%
naruto_master = naruto
one_piece_master = one_piece
big_three_master = big_three

# %%
naruto_master.to_csv('naruto_cleaned.csv', index=False)

# %%
one_piece_master.to_csv('one_piece_cleaned.csv', index=False)

# %%
big_three_master.to_csv('big_three_cleaned.csv', index=False)
